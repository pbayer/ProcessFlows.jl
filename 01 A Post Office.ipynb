# %% [markdown]
# # A Post Office – A Real Life Story
#
# Let us begin with an everyday story: there is a small post office with one clerk serving the arriving customers. Customers have differing wishes leading to different serving times, from ```1 - 5 minutes```. We have to add a little variation to serving times counting for variation in customer habits and clerk performance. The arrival rate of customers is about 18 per hour, every ```3.33 minutes``` or ```3 minutes, 20 seconds``` on average. Our post office is small and customer patience is limited, so queue length is limited to 5 customers.
#
# We have provided 10% extra capacity, so our expectation is that there should not be too many customers discouraged for long waiting times or for full queues.
#
# Let's do a simulation in [```Julia```](https://julialang.org) using [```SimJulia```](https://github.com/BenLauwens/SimJulia.jl). We need
#
# 1. a source: all the people, providing an unlimited supply for customers,
# 2. customers with their demands and their limited patience,
# 3. a queue and
# 4. our good old clerk.

# %%
using SimJulia, Distributions

@resumable function people(sim::Simulation, β::Float64,
                           queue::Array{Int64,1}, clerk::Resource)
    i = 1
    while true
        Δt = rand(Exponential(β))
        @yield return Timeout(sim, Δt)
        @coroutine customer(sim, i, queue, clerk)
        i += 1
    end
end

@resumable function customer(sim::Simulation, n::Int64,
                             queue::Array{Int64,1}, clerk::Resource)
    if length(queue) > 5
        println(@sprintf("%0.2f: Queue is full! Customer %d leaves", now(sim), n))
        return
    else
        arrivaltime = now(sim)
        println(@sprintf("%0.2f: Customer %d enqueues", now(sim), n))
        push!(queue, n)
        @yield return Request(clerk)
        shift!(queue)
        println(@sprintf("%0.2f: Customer %d being served", now(sim), n))
        Δt = rand(DiscreteUniform(1, 5)) + randn()*0.2
        @yield return Timeout(sim, Δt)
        @yield return Release(clerk)
        println(@sprintf("%0.2f: Customer %d leaves after %0.2f min", now(sim), n, now(sim)-arrivaltime))
    end
end

srand(1234)       # seed random number generator for reproducibility
queue = Int64[]
sim = Simulation()
clerk = Resource(sim, 1)
@coroutine people(sim, 3.333, queue, clerk)
run(sim, 600)    # run for 600 minutes
println(queue, " yet in queue")
# Out:
# 8.28: Customer 1 enqueues
# 8.28: Customer 1 being served
# 13.10: Customer 1 leaves after 4.82 min
# 13.33: Customer 2 enqueues
# 13.33: Customer 2 being served
# 17.44: Customer 2 leaves after 4.11 min
# 17.69: Customer 3 enqueues
# 17.69: Customer 3 being served
# 18.84: Customer 4 enqueues
# 19.58: Customer 3 leaves after 1.90 min
# 19.58: Customer 4 being served
# 21.10: Customer 5 enqueues
# 21.61: Customer 4 leaves after 2.77 min
# 21.61: Customer 5 being served
# 24.63: Customer 5 leaves after 3.53 min
# 25.66: Customer 6 enqueues
# 25.66: Customer 6 being served
# 26.72: Customer 7 enqueues
# 27.68: Customer 6 leaves after 2.01 min
# 27.68: Customer 7 being served
# 28.40: Customer 7 leaves after 1.67 min
# 29.60: Customer 8 enqueues
# 29.60: Customer 8 being served
# 33.96: Customer 8 leaves after 4.36 min
# 35.70: Customer 9 enqueues
# 35.70: Customer 9 being served
# 35.94: Customer 10 enqueues
# 37.13: Customer 11 enqueues
# 37.73: Customer 12 enqueues
# 37.85: Customer 9 leaves after 2.15 min
# 37.85: Customer 10 being served
# 40.91: Customer 10 leaves after 4.98 min
# 40.91: Customer 11 being served
# 44.94: Customer 11 leaves after 7.81 min
# 44.94: Customer 12 being served
# 46.12: Customer 12 leaves after 8.39 min
# 47.37: Customer 13 enqueues
# 47.37: Customer 13 being served
# 48.20: Customer 14 enqueues
# 48.34: Customer 15 enqueues
# 48.97: Customer 16 enqueues
# 49.06: Customer 13 leaves after 1.69 min
# 49.06: Customer 14 being served
# 49.46: Customer 17 enqueues
# 49.88: Customer 18 enqueues
# 50.75: Customer 19 enqueues
# 53.79: Customer 14 leaves after 5.59 min
# 53.79: Customer 15 being served
# 54.36: Customer 20 enqueues
# 54.68: Customer 15 leaves after 6.35 min
# 54.68: Customer 16 being served
# 57.08: Customer 21 enqueues
# 58.55: Customer 16 leaves after 9.58 min
# 58.55: Customer 17 being served
# 60.65: Customer 17 leaves after 11.19 min
# 60.65: Customer 18 being served
# 61.18: Customer 22 enqueues
# 62.74: Customer 23 enqueues
# 63.10: Customer 24 enqueues
# 63.59: Customer 18 leaves after 13.71 min
# 63.59: Customer 19 being served
# 64.35: Customer 25 enqueues
# 66.44: Queue is full! Customer 26 leaves
# 66.88: Customer 19 leaves after 16.14 min
# 66.88: Customer 20 being served
# 70.97: Customer 20 leaves after 16.61 min
# 70.97: Customer 21 being served
# 72.05: Customer 21 leaves after 14.96 min
# 72.05: Customer 22 being served
# 77.08: Customer 22 leaves after 15.90 min
# 77.08: Customer 23 being served
# 77.54: Customer 27 enqueues
# 78.51: Customer 28 enqueues
# 81.80: Customer 23 leaves after 19.06 min
# 81.80: Customer 24 being served
# 82.75: Customer 29 enqueues
# 84.48: Customer 24 leaves after 21.38 min
# 84.48: Customer 25 being served
# 86.64: Customer 25 leaves after 22.29 min
# 86.64: Customer 27 being served
# 89.58: Customer 30 enqueues
# 90.69: Customer 27 leaves after 13.15 min
# 90.69: Customer 28 being served
# 91.31: Customer 31 enqueues
# 91.90: Customer 32 enqueues
# 92.53: Customer 28 leaves after 14.03 min
# 92.53: Customer 29 being served
# 95.68: Customer 33 enqueues
# 97.56: Customer 29 leaves after 14.81 min
# 97.56: Customer 30 being served
# 99.50: Customer 30 leaves after 9.92 min
# 99.50: Customer 31 being served
# 102.71: Customer 31 leaves after 11.40 min
# 102.71: Customer 32 being served
# 105.73: Customer 32 leaves after 13.83 min
# 105.73: Customer 33 being served
# 109.12: Customer 34 enqueues
# 109.64: Customer 33 leaves after 13.96 min
# 109.64: Customer 34 being served
# 111.68: Customer 34 leaves after 2.56 min
# 114.66: Customer 35 enqueues
# 114.66: Customer 35 being served
# 116.48: Customer 35 leaves after 1.82 min
# 118.42: Customer 36 enqueues
# 118.42: Customer 36 being served
# 119.07: Customer 37 enqueues
# 123.35: Customer 36 leaves after 4.94 min
# 123.35: Customer 37 being served
# 124.51: Customer 37 leaves after 5.44 min
# 143.74: Customer 38 enqueues
# 143.74: Customer 38 being served
# 147.89: Customer 38 leaves after 4.15 min
# 148.82: Customer 39 enqueues
# 148.82: Customer 39 being served
# 150.89: Customer 40 enqueues
# 153.04: Customer 41 enqueues
# 153.09: Customer 42 enqueues
# 153.73: Customer 39 leaves after 4.91 min
# 153.73: Customer 40 being served
# 158.29: Customer 43 enqueues
# 158.84: Customer 40 leaves after 7.95 min
# 158.84: Customer 41 being served
# 159.70: Customer 44 enqueues
# 159.82: Customer 41 leaves after 6.78 min
# 159.82: Customer 42 being served
# 159.88: Customer 45 enqueues
# 161.63: Customer 42 leaves after 8.54 min
# 161.63: Customer 43 being served
# 163.45: Customer 46 enqueues
# 164.19: Customer 47 enqueues
# 166.67: Customer 43 leaves after 8.38 min
# 166.67: Customer 44 being served
# 167.99: Customer 48 enqueues
# 171.31: Customer 49 enqueues
# 171.81: Customer 44 leaves after 12.12 min
# 171.81: Customer 45 being served
# 175.17: Customer 50 enqueues
# 175.75: Customer 45 leaves after 15.87 min
# 175.75: Customer 46 being served
# 176.55: Customer 46 leaves after 13.10 min
# 176.55: Customer 47 being served
# 179.47: Customer 47 leaves after 15.28 min
# 179.47: Customer 48 being served
# 181.56: Customer 48 leaves after 13.57 min
# 181.56: Customer 49 being served
# 184.24: Customer 51 enqueues
# 184.61: Customer 52 enqueues
# 186.72: Customer 49 leaves after 15.40 min
# 186.72: Customer 50 being served
# 189.90: Customer 53 enqueues
# 190.77: Customer 50 leaves after 15.60 min
# 190.77: Customer 51 being served
# 192.78: Customer 51 leaves after 8.53 min
# 192.78: Customer 52 being served
# 193.78: Customer 54 enqueues
# 196.75: Customer 55 enqueues
# 197.57: Customer 56 enqueues
# 198.02: Customer 52 leaves after 13.41 min
# 198.02: Customer 53 being served
# 200.50: Customer 53 leaves after 10.60 min
# 200.50: Customer 54 being served
# 202.89: Customer 57 enqueues
# 204.80: Customer 54 leaves after 11.02 min
# 204.80: Customer 55 being served
# 204.96: Customer 58 enqueues
# 205.81: Customer 55 leaves after 9.06 min
# 205.81: Customer 56 being served
# 207.79: Customer 59 enqueues
# 210.05: Customer 56 leaves after 12.49 min
# 210.05: Customer 57 being served
# 210.89: Customer 57 leaves after 8.00 min
# 210.89: Customer 58 being served
# 211.64: Customer 58 leaves after 6.68 min
# 211.64: Customer 59 being served
# 212.83: Customer 59 leaves after 5.04 min
# 214.05: Customer 60 enqueues
# 214.05: Customer 60 being served
# 215.61: Customer 61 enqueues
# 217.04: Customer 60 leaves after 2.98 min
# 217.04: Customer 61 being served
# 217.07: Customer 62 enqueues
# 218.34: Customer 63 enqueues
# 222.10: Customer 61 leaves after 6.50 min
# 222.10: Customer 62 being served
# 224.34: Customer 64 enqueues
# 227.44: Customer 62 leaves after 10.37 min
# 227.44: Customer 63 being served
# 228.34: Customer 63 leaves after 10.01 min
# 228.34: Customer 64 being served
# 233.20: Customer 64 leaves after 8.86 min
# 235.51: Customer 65 enqueues
# 235.51: Customer 65 being served
# 236.33: Customer 65 leaves after 0.81 min
# 239.38: Customer 66 enqueues
# 239.38: Customer 66 being served
# 240.25: Customer 66 leaves after 0.87 min
# 243.40: Customer 67 enqueues
# 243.40: Customer 67 being served
# 248.15: Customer 67 leaves after 4.76 min
# 253.08: Customer 68 enqueues
# 253.08: Customer 68 being served
# 254.98: Customer 68 leaves after 1.90 min
# 257.33: Customer 69 enqueues
# 257.33: Customer 69 being served
# 258.62: Customer 70 enqueues
# 259.65: Customer 71 enqueues
# 260.55: Customer 69 leaves after 3.21 min
# 260.55: Customer 70 being served
# 261.56: Customer 70 leaves after 2.94 min
# 261.56: Customer 71 being served
# 265.73: Customer 71 leaves after 6.07 min
# 273.14: Customer 72 enqueues
# 273.14: Customer 72 being served
# 275.09: Customer 73 enqueues
# 278.10: Customer 72 leaves after 4.96 min
# 278.10: Customer 73 being served
# 278.12: Customer 74 enqueues
# 281.47: Customer 75 enqueues
# 283.23: Customer 73 leaves after 8.14 min
# 283.23: Customer 74 being served
# 287.24: Customer 74 leaves after 9.12 min
# 287.24: Customer 75 being served
# 292.24: Customer 75 leaves after 10.77 min
# 293.93: Customer 76 enqueues
# 293.93: Customer 76 being served
# 297.84: Customer 77 enqueues
# 299.01: Customer 76 leaves after 5.09 min
# 299.01: Customer 77 being served
# 300.05: Customer 78 enqueues
# 302.55: Customer 79 enqueues
# 304.08: Customer 80 enqueues
# 304.30: Customer 77 leaves after 6.46 min
# 304.30: Customer 78 being served
# 308.19: Customer 78 leaves after 8.14 min
# 308.19: Customer 79 being served
# 309.67: Customer 81 enqueues
# 311.00: Customer 79 leaves after 8.45 min
# 311.00: Customer 80 being served
# 311.85: Customer 80 leaves after 7.77 min
# 311.85: Customer 81 being served
# 312.57: Customer 81 leaves after 2.90 min
# 317.47: Customer 82 enqueues
# 317.47: Customer 82 being served
# 320.35: Customer 82 leaves after 2.88 min
# 320.95: Customer 83 enqueues
# 320.95: Customer 83 being served
# 323.98: Customer 83 leaves after 3.03 min
# 325.28: Customer 84 enqueues
# 325.28: Customer 84 being served
# 326.57: Customer 85 enqueues
# 327.42: Customer 84 leaves after 2.14 min
# 327.42: Customer 85 being served
# 328.70: Customer 86 enqueues
# 328.88: Customer 87 enqueues
# 329.71: Customer 85 leaves after 3.14 min
# 329.71: Customer 86 being served
# 333.03: Customer 88 enqueues
# 333.69: Customer 86 leaves after 5.00 min
# 333.69: Customer 87 being served
# 333.80: Customer 89 enqueues
# 335.39: Customer 87 leaves after 6.52 min
# 335.39: Customer 88 being served
# 337.13: Customer 88 leaves after 4.10 min
# 337.13: Customer 89 being served
# 337.89: Customer 89 leaves after 4.09 min
# 345.44: Customer 90 enqueues
# 345.44: Customer 90 being served
# 348.54: Customer 91 enqueues
# 349.89: Customer 92 enqueues
# 350.38: Customer 90 leaves after 4.94 min
# 350.38: Customer 91 being served
# 354.45: Customer 91 leaves after 5.92 min
# 354.45: Customer 92 being served
# 356.92: Customer 93 enqueues
# 357.13: Customer 92 leaves after 7.24 min
# 357.13: Customer 93 being served
# 358.90: Customer 94 enqueues
# 360.01: Customer 93 leaves after 3.08 min
# 360.01: Customer 94 being served
# 361.81: Customer 94 leaves after 2.91 min
# 364.10: Customer 95 enqueues
# 364.10: Customer 95 being served
# 364.43: Customer 96 enqueues
# 365.08: Customer 97 enqueues
# 366.96: Customer 98 enqueues
# 368.27: Customer 95 leaves after 4.17 min
# 368.27: Customer 96 being served
# 370.67: Customer 99 enqueues
# 370.74: Customer 100 enqueues
# 371.00: Customer 96 leaves after 6.57 min
# 371.00: Customer 97 being served
# 373.12: Customer 101 enqueues
# 375.31: Customer 97 leaves after 10.24 min
# 375.31: Customer 98 being served
# 375.32: Customer 102 enqueues
# 377.82: Customer 103 enqueues
# 378.63: Customer 104 enqueues
# 379.24: Queue is full! Customer 105 leaves
# 380.23: Customer 98 leaves after 13.27 min
# 380.23: Customer 99 being served
# 382.62: Customer 106 enqueues
# 384.39: Customer 99 leaves after 13.72 min
# 384.39: Customer 100 being served
# 385.60: Customer 100 leaves after 14.86 min
# 385.60: Customer 101 being served
# 386.61: Customer 107 enqueues
# 390.45: Customer 101 leaves after 17.33 min
# 390.45: Customer 102 being served
# 391.46: Customer 102 leaves after 16.14 min
# 391.46: Customer 103 being served
# 393.70: Customer 108 enqueues
# 393.74: Customer 109 enqueues
# 396.43: Customer 103 leaves after 18.61 min
# 396.43: Customer 104 being served
# 399.49: Customer 104 leaves after 20.86 min
# 399.49: Customer 106 being served
# 400.17: Customer 110 enqueues
# 400.54: Customer 111 enqueues
# 400.95: Customer 112 enqueues
# 403.46: Customer 106 leaves after 20.84 min
# 403.46: Customer 107 being served
# 403.57: Customer 113 enqueues
# 406.15: Queue is full! Customer 114 leaves
# 408.18: Customer 107 leaves after 21.57 min
# 408.18: Customer 108 being served
# 408.62: Customer 115 enqueues
# 409.39: Queue is full! Customer 116 leaves
# 411.18: Queue is full! Customer 117 leaves
# 411.52: Customer 108 leaves after 17.82 min
# 411.52: Customer 109 being served
# 411.78: Customer 118 enqueues
# 412.52: Customer 109 leaves after 18.78 min
# 412.52: Customer 110 being served
# 414.44: Customer 119 enqueues
# 414.49: Queue is full! Customer 120 leaves
# 416.51: Customer 110 leaves after 16.34 min
# 416.51: Customer 111 being served
# 417.39: Customer 111 leaves after 16.84 min
# 417.39: Customer 112 being served
# 418.35: Customer 121 enqueues
# 422.18: Customer 112 leaves after 21.23 min
# 422.18: Customer 113 being served
# 423.53: Customer 122 enqueues
# 427.43: Customer 113 leaves after 23.86 min
# 427.43: Customer 115 being served
# 430.50: Customer 123 enqueues
# 431.47: Customer 115 leaves after 22.86 min
# 431.47: Customer 118 being served
# 435.57: Customer 118 leaves after 23.79 min
# 435.57: Customer 119 being served
# 439.41: Customer 119 leaves after 24.97 min
# 439.41: Customer 121 being served
# 439.54: Customer 124 enqueues
# 439.93: Customer 125 enqueues
# 441.20: Customer 121 leaves after 22.85 min
# 441.20: Customer 122 being served
# 441.23: Customer 126 enqueues
# 443.67: Customer 127 enqueues
# 444.01: Customer 128 enqueues
# 446.39: Customer 122 leaves after 22.86 min
# 446.39: Customer 123 being served
# 446.74: Customer 129 enqueues
# 447.04: Queue is full! Customer 130 leaves
# 447.39: Queue is full! Customer 131 leaves
# 450.36: Customer 123 leaves after 19.85 min
# 450.36: Customer 124 being served
# 454.29: Customer 124 leaves after 14.75 min
# 454.29: Customer 125 being served
# 455.30: Customer 125 leaves after 15.37 min
# 455.30: Customer 126 being served
# 456.73: Customer 132 enqueues
# 458.10: Customer 126 leaves after 16.87 min
# 458.10: Customer 127 being served
# 459.30: Customer 133 enqueues
# 460.11: Customer 134 enqueues
# 460.36: Customer 135 enqueues
# 460.90: Customer 127 leaves after 17.23 min
# 460.90: Customer 128 being served
# 466.07: Customer 128 leaves after 22.07 min
# 466.07: Customer 129 being served
# 470.14: Customer 129 leaves after 23.40 min
# 470.14: Customer 132 being served
# 471.45: Customer 132 leaves after 14.72 min
# 471.45: Customer 133 being served
# 474.26: Customer 136 enqueues
# 474.40: Customer 137 enqueues
# 474.92: Customer 138 enqueues
# 476.05: Customer 139 enqueues
# 476.26: Customer 133 leaves after 16.97 min
# 476.26: Customer 134 being served
# 477.43: Customer 140 enqueues
# 477.98: Customer 134 leaves after 17.87 min
# 477.98: Customer 135 being served
# 478.75: Customer 141 enqueues
# 481.86: Queue is full! Customer 142 leaves
# 481.93: Customer 135 leaves after 21.56 min
# 481.93: Customer 136 being served
# 484.54: Customer 143 enqueues
# 484.64: Queue is full! Customer 144 leaves
# 486.76: Customer 136 leaves after 12.50 min
# 486.76: Customer 137 being served
# 487.78: Customer 137 leaves after 13.38 min
# 487.78: Customer 138 being served
# 489.67: Customer 138 leaves after 14.75 min
# 489.67: Customer 139 being served
# 490.51: Customer 145 enqueues
# 491.53: Customer 146 enqueues
# 491.60: Customer 139 leaves after 15.55 min
# 491.60: Customer 140 being served
# 494.95: Customer 147 enqueues
# 496.37: Customer 140 leaves after 18.94 min
# 496.37: Customer 141 being served
# 497.24: Customer 141 leaves after 18.48 min
# 497.24: Customer 143 being served
# 498.33: Customer 148 enqueues
# 501.06: Customer 143 leaves after 16.53 min
# 501.06: Customer 145 being served
# 502.82: Customer 149 enqueues
# 505.81: Customer 145 leaves after 15.31 min
# 505.81: Customer 146 being served
# 505.87: Customer 150 enqueues
# 507.21: Customer 151 enqueues
# 509.75: Customer 146 leaves after 18.22 min
# 509.75: Customer 147 being served
# 514.86: Customer 147 leaves after 19.91 min
# 514.86: Customer 148 being served
# 516.01: Customer 148 leaves after 17.68 min
# 516.01: Customer 149 being served
# 518.75: Customer 152 enqueues
# 519.13: Customer 149 leaves after 16.31 min
# 519.13: Customer 150 being served
# 521.06: Customer 153 enqueues
# 521.73: Customer 154 enqueues
# 522.81: Customer 150 leaves after 16.93 min
# 522.81: Customer 151 being served
# 523.49: Customer 151 leaves after 16.28 min
# 523.49: Customer 152 being served
# 524.56: Customer 155 enqueues
# 526.43: Customer 152 leaves after 7.68 min
# 526.43: Customer 153 being served
# 529.58: Customer 153 leaves after 8.52 min
# 529.58: Customer 154 being served
# 530.57: Customer 154 leaves after 8.84 min
# 530.57: Customer 155 being served
# 531.07: Customer 156 enqueues
# 533.61: Customer 155 leaves after 9.05 min
# 533.61: Customer 156 being served
# 535.70: Customer 156 leaves after 4.63 min
# 536.55: Customer 157 enqueues
# 536.55: Customer 157 being served
# 539.73: Customer 158 enqueues
# 540.58: Customer 157 leaves after 4.03 min
# 540.58: Customer 158 being served
# 541.35: Customer 158 leaves after 1.61 min
# 549.26: Customer 159 enqueues
# 549.26: Customer 159 being served
# 550.26: Customer 159 leaves after 1.00 min
# 560.39: Customer 160 enqueues
# 560.39: Customer 160 being served
# 563.40: Customer 160 leaves after 3.01 min
# 565.11: Customer 161 enqueues
# 565.11: Customer 161 being served
# 565.93: Customer 161 leaves after 0.82 min
# 566.95: Customer 162 enqueues
# 566.95: Customer 162 being served
# 567.90: Customer 162 leaves after 0.95 min
# 567.93: Customer 163 enqueues
# 567.93: Customer 163 being served
# 572.02: Customer 164 enqueues
# 572.77: Customer 163 leaves after 4.84 min
# 572.77: Customer 164 being served
# 575.72: Customer 165 enqueues
# 575.91: Customer 164 leaves after 3.89 min
# 575.91: Customer 165 being served
# 577.17: Customer 166 enqueues
# 580.13: Customer 165 leaves after 4.41 min
# 580.13: Customer 166 being served
# 581.06: Customer 167 enqueues
# 583.18: Customer 166 leaves after 6.02 min
# 583.18: Customer 167 being served
# 586.51: Customer 168 enqueues
# 587.07: Customer 167 leaves after 6.01 min
# 587.07: Customer 168 being served
# 592.47: Customer 168 leaves after 5.96 min
# 595.56: Customer 169 enqueues
# 595.56: Customer 169 being served
# 598.80: Customer 170 enqueues
# 599.15: Customer 171 enqueues
# 599.37: Customer 169 leaves after 3.81 min
# 599.37: Customer 170 being served
# 599.84: Customer 172 enqueues
# [171, 172] yet in queue

# %% [markdown]
# We did run the simulation 600 minutes. 172 customers came, 160 customers were served, 10 left beforehand because the queue was full, 2 were still in queue when simulation was over. Many customers had waiting times of meor than 10, 15 or even 20 minutes.
#
# So many customers will remain angry. If this is the situation all days, our post office will have an evil reputation. What should we do?
#
# ## Conclusion
#
# What we see here are the **effects of variation** in arrivals, in demands and in serving time on system performance. In this case 10% extra capacity is not enough to provide for variation and to serve the customers well.
#
# This is what this Repository ```PFlow``` is all about: to get systems flowing and to see what may happen beforehand before the system breaks down.
